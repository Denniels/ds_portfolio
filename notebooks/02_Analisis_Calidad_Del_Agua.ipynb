# %% [markdown]
# # Análisis de Calidad del Agua en Chile
#
# Este notebook analiza la calidad del agua en diferentes regiones de Chile utilizando datos de estaciones de monitoreo.

# %%
# Importar bibliotecas
import pandas as pd
import plotly.express as px
import folium
from pathlib import Path

# %% [markdown]
# ## Datos de Estaciones
#
# Creamos un conjunto de datos de ejemplo con estaciones de monitoreo.

# %%
# Datos de ejemplo de estaciones
stations_data = {
    'station_name': [
        'Estación Maipo', 'Estación Mapocho', 'Estación Biobío',
        'Estación Cautín', 'Estación Valdivia'
    ],
    'region': [
        'Metropolitana', 'Metropolitana', 'Biobío',
        'Araucanía', 'Los Ríos'
    ],
    'water_quality_index': [78, 72, 85, 88, 92],
    'latitude': [-33.6147, -33.4331, -36.8384, -38.7359, -39.8142],
    'longitude': [-70.9758, -70.6503, -73.0496, -72.6667, -73.2320]
}

df = pd.DataFrame(stations_data)
df.head()

# %% [markdown]
# ## Visualización Geográfica
#
# Creamos un mapa interactivo con las estaciones de monitoreo.

# %%
# Crear mapa base
m = folium.Map(
    location=[-33.4489, -70.6693],
    zoom_start=5,
    tiles='OpenStreetMap'
)

# Agregar marcadores
for idx, row in df.iterrows():
    folium.Marker(
        [row['latitude'], row['longitude']],
        popup=f"Estación: {row['station_name']}<br>Calidad: {row['water_quality_index']}",
        tooltip=row['station_name']
    ).add_to(m)

m

# %% [markdown]
# ## Análisis por Región
#
# Analizamos la calidad del agua por región.

# %%
# Gráfico de calidad por región
fig = px.bar(
    df,
    x='region',
    y='water_quality_index',
    title='Índice de Calidad del Agua por Región',
    labels={
        'region': 'Región',
        'water_quality_index': 'Índice de Calidad del Agua'
    }
)
fig.show()

# %% [markdown]
# ## Estadísticas Descriptivas
#
# Calculamos estadísticas básicas de calidad del agua.

# %%
# Estadísticas por región
stats = df.groupby('region')['water_quality_index'].describe()
stats
