# %% [markdown]
# # Análisis del Presupuesto Público de Chile
#
# Este notebook analiza la distribución y evolución del presupuesto público en Chile.

# %%
# Importar bibliotecas necesarias
import pandas as pd
import plotly.express as px
import numpy as np
from pathlib import Path

# %% [markdown]
# ## Datos Presupuestarios
#
# Generamos datos de ejemplo del presupuesto público.

# %%
# Crear datos de ejemplo
budget_data = {
    'year': [2023] * 5 + [2024] * 5,
    'ministry': ['Educación', 'Salud', 'Vivienda', 'Obras Públicas', 'Desarrollo Social'] * 2,
    'program': ['Programa 1', 'Programa 2', 'Programa 3', 'Programa 4', 'Programa 5'] * 2,
    'budget': [1000000, 800000, 600000, 500000, 400000] * 2
}

df = pd.DataFrame(budget_data)
df.head()

# %% [markdown]
# ## Distribución por Ministerio
#
# Analizamos cómo se distribuye el presupuesto entre ministerios.

# %%
# Gráfico de distribución por ministerio
fig = px.treemap(
    df,
    path=['ministry', 'program'],
    values='budget',
    title='Distribución del Presupuesto por Ministerio',
    color='budget',
    color_continuous_scale='Viridis'
)
fig.show()

# %% [markdown]
# ## Análisis Temporal
#
# Examinamos la evolución del presupuesto en el tiempo.

# %%
# Evolución temporal por ministerio
ministry_totals = df.groupby(['year', 'ministry'])['budget'].sum().reset_index()

fig = px.line(
    ministry_totals,
    x='year',
    y='budget',
    color='ministry',
    title='Evolución del Presupuesto por Ministerio',
    labels={
        'year': 'Año',
        'budget': 'Presupuesto (MM$)',
        'ministry': 'Ministerio'
    }
)
fig.show()

# %% [markdown]
# ## Estadísticas por Programa
#
# Analizamos la distribución a nivel de programas.

# %%
# Estadísticas por programa
program_stats = df.groupby('program')['budget'].agg(['mean', 'std', 'min', 'max'])
program_stats
